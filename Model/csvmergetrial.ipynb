# %%
import pandas as pd

routedf = pd.read_csv('CSVLib\RoutesRaw.csv', header=1)
locs = pd.read_csv('CSVLib\Locations.csv',header=0)


newdf = pd.DataFrame(columns=["Start","StartLat","StartLon", "End","EndLat","EndLon", "Units", "Trucks"])
for i in range(routedf.shape[0]):
    startid = routedf.values[i][1]
    endid = routedf.values[i][2]
    startlat,startlon = locs.loc[locs['ID'] == startid].values[0][2],locs.loc[locs['ID'] == startid].values[0][3]
    endlat,endlon = locs.loc[locs['ID'] == endid].values[0][2], locs.loc[locs['ID'] == endid].values[0][2]
    
    newdf.loc[len(newdf)] = [startid,startlat,startlon,endid,endlat,endlon,routedf.values[i][3],routedf.values[i][4]]
    
newdf.to_csv("CSVLib\Routes.csv")
# Out:
# 2.0
# 2.0
# 2.0
# 3.0
# 3.0
# 3.0
# 4.0
# 4.0
# 5.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 7.0
# 7.0
# 7.0
# 7.0
# 7.0
# 7.0
# 8.0
# 8.0
# 8.0
# 8.0
# 8.0
# 9.0
# 9.0
# 10.0
# 11.0
# 11.0
# 11.0
# 11.0
# 11.0
# 11.0
# 11.0
# 12.0
# 12.0
# 12.0
# 12.0
# 12.0
# 12.0
# 13.0
# 14.0
# 15.0
# 15.0
# 15.0
# 16.0
# 16.0
# 16.0
# 16.0
# 16.0
# 17.0
# 18.0
# 19.0
# 20.0
# 20.0
# 20.0
# 22.0
# 22.0
# 22.0
# 22.0
# 23.0
# 23.0
# 23.0
# 23.0
# 23.0
# 23.0
# 25.0

# %%
newdf
# Out:
#     Start   StartLat   StartLon   End   EndLat   EndLon      Units  Trucks
# 0     2.0  27.461163 -82.540418  60.0  26.6630  26.6630  2328785.0   146.0
# 1     2.0  27.461163 -82.540418  65.0  27.4799  27.4799  2851777.0   179.0
# 2     2.0  27.461163 -82.540418  81.0  27.3364  27.3364  3096465.0   194.0
# 3     3.0  30.262235 -81.605391  40.0  30.3322  30.3322  7102987.0   444.0
# 4     3.0  30.262235 -81.605391  70.0  30.5927  30.5927   644626.0    41.0
# ..    ...        ...        ...   ...      ...      ...        ...     ...
# 63   23.0  30.887564 -85.335709  71.0  30.5773  30.5773  1510169.0    95.0
# 64   23.0  30.887564 -85.335709  80.0  30.7690  30.7690  1341307.0    84.0
# 65   23.0  30.887564 -85.335709  91.0  30.5643  30.5643   535674.0    34.0
# 66   23.0  30.887564 -85.335709  92.0  30.6084  30.6084   181254.0    12.0
# 67   25.0  28.027583 -82.357688  53.0  27.9904  27.9904  2251351.0   141.0
#
# [68 rows x 8 columns]

# %%
import csv
routes = pd.read_csv("CSVLib\Routes.csv",header=1)

for i in range(routes.shape[0]):
    startlat, startlon = routes.values[i][2], routes.values[i][3]
    endlat, endlon = routes.values[i][5], routes.values[i][6]
# Out:
# 27.461163
# 27.461163
# 30.262235
# 30.262235
# 30.262235
# 28.638841
# 28.638841
# 29.232575
# 30.47227
# 30.47227
# 30.47227
# 30.47227
# 30.47227
# 29.818485
# 29.818485
# 29.818485
# 29.818485
# 29.818485
# 29.818485
# 30.820875
# 30.820875
# 30.820875
# 30.820875
# 30.820875
# 29.508083
# 29.508083
# 28.616443
# 26.904652
# 26.904652
# 26.904652
# 26.904652
# 26.904652
# 26.904652
# 26.904652
# 27.958677
# 27.958677
# 27.958677
# 27.958677
# 27.958677
# 27.958677
# 29.183999
# 26.191601
# 25.872969
# 25.872969
# 25.872969
# 30.521513
# 30.521513
# 30.521513
# 30.521513
# 30.521513
# 27.865073
# 28.039732
# 28.007697
# 30.1345513
# 30.1345513
# 30.1345513
# 28.582968
# 28.582968
# 28.582968
# 28.582968
# 30.887564
# 30.887564
# 30.887564
# 30.887564
# 30.887564
# 30.887564
# 28.027583
